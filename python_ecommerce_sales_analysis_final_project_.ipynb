# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-bab74e34-00ff-4dcd-888e-1ffe4c419092" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bab74e34-00ff-4dcd-888e-1ffe4c419092">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("dataset_ecommerce_sales_final_project.csv")

df
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 0    ORD-0001     2026-05-03         Ali    Trabzon       Kitap
# 1    ORD-0002     2026-06-07       Ceren      Konya        Moda
# 2    ORD-0003     2026-05-25      Zeynep  Eskişehir        Spor
# 3    ORD-0004     2026-05-19        Tuna      Konya     Oyuncak
# 4    ORD-0005     2026-05-25       Ceren      Bursa  Ev & Yaşam
# ..        ...            ...         ...        ...         ...
# 95   ORD-0096     2026-06-07       Derya      Adana      Market
# 96   ORD-0097     2026-06-10        Tuna      Muğla  Elektronik
# 97   ORD-0098     2026-06-26        Emre      Adana      Market
# 98   ORD-0099     2026-06-11      Zeynep      İzmir    Kozmetik
# 99   ORD-0100     2026-06-13         Efe  Eskişehir       Kitap
#
#                       urun uyelik_tipi odeme_yontemi  urun_fiyati  adet  \
# 0                    Roman    Standart   Kredi Kartı          470     1
# ...

# %%
df.head(20)
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 0    ORD-0001     2026-05-03         Ali    Trabzon       Kitap
# 1    ORD-0002     2026-06-07       Ceren      Konya        Moda
# 2    ORD-0003     2026-05-25      Zeynep  Eskişehir        Spor
# 3    ORD-0004     2026-05-19        Tuna      Konya     Oyuncak
# 4    ORD-0005     2026-05-25       Ceren      Bursa  Ev & Yaşam
# 5    ORD-0006     2026-05-11        Emre     Ankara       Kitap
# 6    ORD-0007     2026-06-19        Ayşe  Eskişehir  Elektronik
# 7    ORD-0008     2026-06-01       Derya  Eskişehir     Oyuncak
# 8    ORD-0009     2026-05-09        İrem      Muğla  Elektronik
# 9    ORD-0010     2026-06-08        Buse      Muğla  Elektronik
# 10   ORD-0011     2026-05-28        Elif  Eskişehir      Market
# 11   ORD-0012     2026-06-02        Mina    Antalya  Elektronik
# 12   ORD-0013     2026-05-08       Barış  Eskişehir  Elektronik
# 13   ORD-0014     2026-05-09        Kaan      Adana     Oyuncak
# ...

# %%
df.tail(20)
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 80   ORD-0081     2026-06-25         Can      Muğla        Moda
# 81   ORD-0082     2026-05-16        Aslı      Bursa  Ev & Yaşam
# 82   ORD-0083     2026-06-20        Tuna      Konya        Moda
# 83   ORD-0084     2026-05-01        Arda      Adana  Ev & Yaşam
# 84   ORD-0085     2026-06-24       Selin      Konya    Kozmetik
# 85   ORD-0086     2026-06-17      Mehmet    Antalya      Market
# 86   ORD-0087     2026-05-24       Kerem   İstanbul      Market
# 87   ORD-0088     2026-05-16        Onur      Konya        Moda
# 88   ORD-0089     2026-05-11      Mehmet    Antalya        Moda
# 89   ORD-0090     2026-05-25       Eylül    Antalya      Market
# 90   ORD-0091     2026-06-06       Eylül      Konya  Elektronik
# 91   ORD-0092     2026-05-13        Mina  Eskişehir      Market
# 92   ORD-0093     2026-06-16         Can      Adana       Kitap
# 93   ORD-0094     2026-06-28       Ceren  Eskişehir      Market
# ...

# %%
df.shape
# Out:
# (100, 14)

# %%
df.columns
# Out:
# Index(['siparis_id', 'siparis_tarihi', 'musteri_adi', 'sehir', 'kategori',
#        'urun', 'uyelik_tipi', 'odeme_yontemi', 'urun_fiyati', 'adet',
#        'indirim_orani', 'toplam_tutar', 'kargo_suresi_gun', 'siparis_durumu'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   siparis_id        100 non-null    object
#  1   siparis_tarihi    100 non-null    object
#  2   musteri_adi       100 non-null    object
#  3   sehir             100 non-null    object
#  4   kategori          100 non-null    object
#  5   urun              100 non-null    object
#  6   uyelik_tipi       100 non-null    object
#  7   odeme_yontemi     100 non-null    object
#  8   urun_fiyati       100 non-null    int64
#  9   adet              100 non-null    int64
#  10  indirim_orani     100 non-null    float64
#  11  toplam_tutar      100 non-null    float64
#  12  kargo_suresi_gun  100 non-null    int64
#  13  siparis_durumu    100 non-null    object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        urun_fiyati        adet  indirim_orani  toplam_tutar  kargo_suresi_gun
# count   100.000000  100.000000     100.000000    100.000000        100.000000
# mean    931.100000    2.000000       0.046000   1758.780000          2.920000
# std     736.343539    1.214392       0.041243   1854.705844          1.203362
# min     100.000000    1.000000       0.000000    100.000000          1.000000
# 25%     440.000000    1.000000       0.000000    606.750000          2.000000
# 50%     695.000000    1.500000       0.050000   1173.000000          3.000000
# 75%    1185.000000    3.000000       0.050000   2240.500000          4.000000
# max    3410.000000    5.000000       0.150000  10800.000000          7.000000

# %% [markdown]
# **Genel İçgörü**
#
#
# *   Ortalama sipariş tutarı yaklaşık 1759 TL'dir.
# *   Müşterilerin harcama tutarları arasında belirgin farklar bulunmaktadır.
#
#
# *   Kargo süreleri genel olarak kısa görünmektedir. Ancak sipariş tutarları birbirinden oldukça farklıdır.
# *  Veri seti, farklı müşteri gruplarının olduğunu göstermektedir. Bu nedenle müşterileri segmentlere ayırarak analiz yapmak daha faydalı olabilir.

# %%
df["toplam_tutar"].mean()
# Out:
# np.float64(1758.78)

# %%
df["toplam_tutar"].median()
# Out:
# 1173.0

# %%
print("En dusuk siparis tutari:", df["toplam_tutar"].min())
print("En yuksek siparis tutari:", df["toplam_tutar"].max())
# Out:
# En dusuk siparis tutari: 100.0
# En yuksek siparis tutari: 10800.0

# %%
tamamlanan_siparisler = df[df["siparis_durumu"] == "Tamamlandı"]

toplam_ciro = tamamlanan_siparisler["toplam_tutar"].sum()

print("Toplam Ciro:", toplam_ciro)
# Out:
# Toplam Ciro: 158271.5

# %%
tamamlanma_orani= (df["siparis_durumu"] == "Tamamlandı").mean() *100

print("Tamamlanan Siparis Orani:", tamamlanma_orani)
# Out:
# Tamamlanan Siparis Orani: 89.0

# %%
df[df["toplam_tutar"] > 1000]
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 1    ORD-0002     2026-06-07       Ceren      Konya        Moda
# 2    ORD-0003     2026-05-25      Zeynep  Eskişehir        Spor
# 6    ORD-0007     2026-06-19        Ayşe  Eskişehir  Elektronik
# 8    ORD-0009     2026-05-09        İrem      Muğla  Elektronik
# 9    ORD-0010     2026-06-08        Buse      Muğla  Elektronik
# 11   ORD-0012     2026-06-02        Mina    Antalya  Elektronik
# 12   ORD-0013     2026-05-08       Barış  Eskişehir  Elektronik
# 16   ORD-0017     2026-06-01       Burak      Bursa  Elektronik
# 17   ORD-0018     2026-05-28         Efe     Ankara        Spor
# 18   ORD-0019     2026-05-07       Deniz  Eskişehir    Kozmetik
# 20   ORD-0021     2026-05-31       Burak      İzmir  Elektronik
# 21   ORD-0022     2026-05-10       Burak      Adana      Market
# 22   ORD-0023     2026-05-04        İrem      Muğla        Moda
# 23   ORD-0024     2026-06-09      Mehmet      Muğla     Oyuncak
# ...

# %%
df[df["uyelik_tipi"] == "Gold"]
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 7    ORD-0008     2026-06-01       Derya  Eskişehir     Oyuncak
# 10   ORD-0011     2026-05-28        Elif  Eskişehir      Market
# 16   ORD-0017     2026-06-01       Burak      Bursa  Elektronik
# 20   ORD-0021     2026-05-31       Burak      İzmir  Elektronik
# 26   ORD-0027     2026-06-12        Tuna      Muğla      Market
# 28   ORD-0029     2026-05-03         Ali      Konya        Moda
# 41   ORD-0042     2026-06-26     Yasemin     Ankara        Moda
# 49   ORD-0050     2026-06-07        Aslı    Trabzon        Moda
# 57   ORD-0058     2026-05-21       Eylül      Adana    Kozmetik
# 71   ORD-0072     2026-05-18        İrem      Adana  Elektronik
# 78   ORD-0079     2026-05-18       Kerem    Antalya  Elektronik
# 86   ORD-0087     2026-05-24       Kerem   İstanbul      Market
# 88   ORD-0089     2026-05-11      Mehmet    Antalya        Moda
# 90   ORD-0091     2026-06-06       Eylül      Konya  Elektronik
# ...

# %%
df[df["kategori"] == "Elektronik"]
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 6    ORD-0007     2026-06-19        Ayşe  Eskişehir  Elektronik
# 8    ORD-0009     2026-05-09        İrem      Muğla  Elektronik
# 9    ORD-0010     2026-06-08        Buse      Muğla  Elektronik
# 11   ORD-0012     2026-06-02        Mina    Antalya  Elektronik
# 12   ORD-0013     2026-05-08       Barış  Eskişehir  Elektronik
# 16   ORD-0017     2026-06-01       Burak      Bursa  Elektronik
# 20   ORD-0021     2026-05-31       Burak      İzmir  Elektronik
# 43   ORD-0044     2026-06-18       Gizem    Trabzon  Elektronik
# 46   ORD-0047     2026-05-27        Ayşe  Eskişehir  Elektronik
# 50   ORD-0051     2026-05-22       Melis      Bursa  Elektronik
# 55   ORD-0056     2026-05-28        Kaan   İstanbul  Elektronik
# 56   ORD-0057     2026-06-23        Buse  Eskişehir  Elektronik
# 64   ORD-0065     2026-06-18        Onur      İzmir  Elektronik
# 69   ORD-0070     2026-05-30      Mehmet    Antalya  Elektronik
# ...

# %%
df[df["siparis_durumu"] == "Tamamlandı"]
# Out:
#    siparis_id siparis_tarihi musteri_adi      sehir    kategori  \
# 0    ORD-0001     2026-05-03         Ali    Trabzon       Kitap
# 1    ORD-0002     2026-06-07       Ceren      Konya        Moda
# 2    ORD-0003     2026-05-25      Zeynep  Eskişehir        Spor
# 3    ORD-0004     2026-05-19        Tuna      Konya     Oyuncak
# 4    ORD-0005     2026-05-25       Ceren      Bursa  Ev & Yaşam
# ..        ...            ...         ...        ...         ...
# 95   ORD-0096     2026-06-07       Derya      Adana      Market
# 96   ORD-0097     2026-06-10        Tuna      Muğla  Elektronik
# 97   ORD-0098     2026-06-26        Emre      Adana      Market
# 98   ORD-0099     2026-06-11      Zeynep      İzmir    Kozmetik
# 99   ORD-0100     2026-06-13         Efe  Eskişehir       Kitap
#
#                       urun uyelik_tipi odeme_yontemi  urun_fiyati  adet  \
# 0                    Roman    Standart   Kredi Kartı          470     1
# ...

# %%
df[
    (df["uyelik_tipi"] == "Gold")
    &
    (df["toplam_tutar"] > 1000)
]
# Out:
#    siparis_id siparis_tarihi musteri_adi    sehir    kategori  \
# 16   ORD-0017     2026-06-01       Burak    Bursa  Elektronik
# 20   ORD-0021     2026-05-31       Burak    İzmir  Elektronik
# 49   ORD-0050     2026-06-07        Aslı  Trabzon        Moda
# 57   ORD-0058     2026-05-21       Eylül    Adana    Kozmetik
# 71   ORD-0072     2026-05-18        İrem    Adana  Elektronik
# 78   ORD-0079     2026-05-18       Kerem  Antalya  Elektronik
# 88   ORD-0089     2026-05-11      Mehmet  Antalya        Moda
# 90   ORD-0091     2026-06-06       Eylül    Konya  Elektronik
# 94   ORD-0095     2026-06-18       Deniz    Adana        Moda
# 96   ORD-0097     2026-06-10        Tuna    Muğla  Elektronik
# 98   ORD-0099     2026-06-11      Zeynep    İzmir    Kozmetik
#
#                   urun uyelik_tipi odeme_yontemi  urun_fiyati  adet  \
# 16  Bluetooth Kulaklık        Gold   Banka Kartı         1150     4
# 20      Kablosuz Mouse        Gold  Kapıda Ödeme         3000     4
# ...

# %%
df.groupby("uyelik_tipi")["toplam_tutar"].mean()
# Out:
# uyelik_tipi
# Gold        2515.500000
# Silver      1743.305556
# Standart    1496.925532
# Name: toplam_tutar, dtype: float64

# %%
tamamlanan_siparisler.groupby("kategori")["toplam_tutar"].sum().sort_values(ascending=False)
# Out:
# kategori
# Elektronik    67428.5
# Moda          23174.0
# Kozmetik      22029.0
# Market        18591.0
# Oyuncak        8618.5
# Kitap          7126.5
# Spor           6948.0
# Ev & Yaşam     4356.0
# Name: toplam_tutar, dtype: float64

# %%
tamamlanan_siparisler.groupby("sehir")["toplam_tutar"].sum().sort_values(ascending=False)
# Out:
# sehir
# Eskişehir    25195.5
# Adana        21680.5
# İzmir        19130.0
# Antalya      19015.0
# Konya        18021.5
# Muğla        15341.0
# Ankara       12969.5
# Bursa        11071.0
# İstanbul      9951.5
# Trabzon       5896.0
# Name: toplam_tutar, dtype: float64

# %%
df["siparis_durumu"].value_counts()
# Out:
# siparis_durumu
# Tamamlandı    89
# İptal          8
# İade           3
# Name: count, dtype: int64

# %%
df.groupby("kategori")["kargo_suresi_gun"].mean().sort_values(ascending=False)
# Out:
# kategori
# Oyuncak       3.555556
# Elektronik    3.277778
# Kitap         3.000000
# Ev & Yaşam    3.000000
# Market        2.750000
# Kozmetik      2.714286
# Moda          2.687500
# Spor          2.500000
# Name: kargo_suresi_gun, dtype: float64

# %%
df.select_dtypes(include="number").corr()
# Out:
#                   urun_fiyati      adet  indirim_orani  toplam_tutar  \
# urun_fiyati          1.000000 -0.000452       0.132856      0.764104
# adet                -0.000452  1.000000      -0.030251      0.513181
# indirim_orani        0.132856 -0.030251       1.000000      0.169830
# toplam_tutar         0.764104  0.513181       0.169830      1.000000
# kargo_suresi_gun     0.135641  0.124418       0.034192      0.166860
#
#                   kargo_suresi_gun
# urun_fiyati               0.135641
# adet                      0.124418
# indirim_orani             0.034192
# toplam_tutar              0.166860
# kargo_suresi_gun          1.000000

# %% [markdown]
# **Genel Değerlendirme**
#
# *   En güçlü ilişki ürün fiyatı ile toplam sipariş tutarı arasındadır. Korelasyon değeri 0.76 olduğu için aralarında güçlü bir ilişki olduğu söylenebilir.
# *   Sipariş adedi de toplam sipariş tutarını etkileyen önemli faktörlerden biridir.
#
# *   İndirim oranı ve kargo süresinin ise toplam sipariş tutarı üzerinde belirgin bir etkisi görünmemektedir.

# %%
df[df["toplam_tutar"] == df["toplam_tutar"].max()]
# Out:
#    siparis_id siparis_tarihi musteri_adi  sehir    kategori            urun  \
# 20   ORD-0021     2026-05-31       Burak  İzmir  Elektronik  Kablosuz Mouse
#
#    uyelik_tipi odeme_yontemi  urun_fiyati  adet  indirim_orani  toplam_tutar  \
# 20        Gold  Kapıda Ödeme         3000     4            0.1       10800.0
#
#     kargo_suresi_gun siparis_durumu
# 20                 4     Tamamlandı

# %%
tamamlanan_siparisler.groupby("kategori")["toplam_tutar"].sum().sort_values(ascending=False).head(1)
# Out:
# kategori
# Elektronik    67428.5
# Name: toplam_tutar, dtype: float64

# %%
df.groupby("uyelik_tipi")["toplam_tutar"].mean().sort_values(ascending=False)
# Out:
# uyelik_tipi
# Gold        2515.500000
# Silver      1743.305556
# Standart    1496.925532
# Name: toplam_tutar, dtype: float64

# %%
tamamlanan_siparisler.groupby("sehir")["toplam_tutar"].sum().sort_values(ascending=False).head(1)
# Out:
# sehir
# Eskişehir    25195.5
# Name: toplam_tutar, dtype: float64

# %%
df["kargo_suresi_gun"].mean()
# Out:
# np.float64(2.92)

# %%
print("İçgörü 1: Ortalama sipariş tutarı yaklaşık 1759 TL'dir. Medyanın 1173 TL olması, bazı yüksek tutarlı siparişlerin ortalamayı artırdığını düşündürüyor.")

print("İçgörü 2: Tamamlanan siparişlerden elde edilen toplam ciro yaklaşık 158272 TL'dir.")

print("İçgörü 3: En fazla ciro Elektronik kategorisinden elde edilmiştir. Bu yüzden bu kategoriye daha fazla önem verilebilir.")

print("İçgörü 4: Gold üyelerin ortalama sipariş tutarı Standart üyelere göre daha yüksektir. Bu da üyelik seviyesinin harcama üzerinde etkili olabileceğini gösteriyor.")

print("İçgörü 5: Standart sapmanın yüksek olması, sipariş tutarlarının birbirinden farklı olduğunu gösteriyor. Bu nedenle müşterileri harcama miktarına göre gruplandırmak faydalı olabilir.")
# Out:
# İçgörü 1: Ortalama sipariş tutarı yaklaşık 1759 TL'dir. Medyanın 1173 TL olması, bazı yüksek tutarlı siparişlerin ortalamayı artırdığını düşündürüyor.
# İçgörü 2: Tamamlanan siparişlerden elde edilen toplam ciro yaklaşık 158272 TL'dir.
# İçgörü 3: En fazla ciro Elektronik kategorisinden elde edilmiştir. Bu yüzden bu kategoriye daha fazla önem verilebilir.
# İçgörü 4: Gold üyelerin ortalama sipariş tutarı Standart üyelere göre daha yüksektir. Bu da üyelik seviyesinin harcama üzerinde etkili olabileceğini gösteriyor.
# İçgörü 5: Standart sapmanın yüksek olması, sipariş tutarlarının birbirinden farklı olduğunu gösteriyor. Bu nedenle müşterileri harcama miktarına göre gruplandırmak faydalı olabilir.
